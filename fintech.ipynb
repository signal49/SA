# %%
import polars as pl
from datetime import datetime

df1 = pl.DataFrame(
    {
        "Date": ['2000-01-01'],
        "Open": [20.000001],
        "High": [20.000001],
        "Low": [20.000001],
        "Close": [20.00001],
        "Adj Close":[20.000001],
        "Volume":[123456],
        "Ticker":['NONE']
    }
)

df1 = df1.clear()

# %%
#try:
#    df1 = df1.with_columns(pl.col("Date").str.to_date())
#except Exception as e:
#    print(e)

print(df1)
# Out:
# shape: (0, 8)
# ┌──────┬──────┬──────┬─────┬───────┬───────────┬────────┬────────┐
# │ Date ┆ Open ┆ High ┆ Low ┆ Close ┆ Adj Close ┆ Volume ┆ Ticker │
# │ ---  ┆ ---  ┆ ---  ┆ --- ┆ ---   ┆ ---       ┆ ---    ┆ ---    │
# │ str  ┆ f64  ┆ f64  ┆ f64 ┆ f64   ┆ f64       ┆ i64    ┆ str    │
# ╞══════╪══════╪══════╪═════╪═══════╪═══════════╪════════╪════════╡
# └──────┴──────┴──────┴─────┴───────┴───────────┴────────┴────────┘

# %%
#df_msft = pl.read_csv("stocks/MSFT.csv")

# %%
#df_msft = df_msft.with_columns(Ticker=pl.lit('MSFT'))

# %%
#print(df_msft)

# %%
#sp500_df = pl.concat([df1,df_msft], rechunk=True) #new memory slab

# %%
#print(sp500_df)

# %%
#try:
#    goog_df = pl.read_csv("stocks/GOOG.csv")
#    goog_df = goog_df.with_columns(Ticker=pl.lit('GOOG'))
#    sp500_df = pl.concat([sp500_df,goog_df], rechunk=True) #new memory slab
#except:
#    print("didn't work")

# %%
#print(sp500_df)

# %%
spDict = {
'MMM'  : 'MMM_df', 
'AOS'  : 'AOS_df', 
'ABT'  : 'ABT_df', 
'ABBV'  : 'ABBV_df', 
'ACN'  : 'ACN_df', 
'ADBE'  : 'ADBE_df', 
'AMD'  : 'AMD_df', 
'AES'  : 'AES_df', 
'AFL'  : 'AFL_df', 
'A'  : 'A_df', 
'APD'  : 'APD_df', 
'ABNB'  : 'ABNB_df', 
'AKAM'  : 'AKAM_df', 
'ALB'  : 'ALB_df', 
'ARE'  : 'ARE_df', 
'ALGN'  : 'ALGN_df', 
'ALLE'  : 'ALLE_df', 
'LNT'  : 'LNT_df', 
'ALL'  : 'ALL_df', 
'GOOG'  : 'GOOG_df', 
'GOOGL'  : 'GOOGL_df', #added 4/3/2014
'MO'  : 'MO_df', 
'AMZN'  : 'AMZN_df', 
'AMCR'  : 'AMCR_df', 
'AEE'  : 'AEE_df', 
'AAL'  : 'AAL_df', 
'AEP'  : 'AEP_df', 
'AXP'  : 'AXP_df', 
'AIG'  : 'AIG_df', 
'AMT'  : 'AMT_df', 
'AWK'  : 'AWK_df', 
'AMP'  : 'AMP_df', 
'AME'  : 'AME_df', 
'AMGN'  : 'AMGN_df', 
'APH'  : 'APH_df', 
'ADI'  : 'ADI_df', 
'ANSS'  : 'ANSS_df', 
'AON'  : 'AON_df', 
'APA'  : 'APA_df', 
'AAPL'  : 'AAPL_df', 
'AMAT'  : 'AMAT_df', 
'APTV'  : 'APTV_df', 
'ACGL'  : 'ACGL_df', 
'ADM'  : 'ADM_df', 
'ANET'  : 'ANET_df', 
'AJG'  : 'AJG_df', 
'AIZ'  : 'AIZ_df', 
'T'  : 'T_df', 
'ATO'  : 'ATO_df', 
'ADSK'  : 'ADSK_df', 
'ADP'  : 'ADP_df', 
'AZO'  : 'AZO_df', 
'AVB'  : 'AVB_df', 
'AVY'  : 'AVY_df', 
'AXON'  : 'AXON_df', 
'BKR'  : 'BKR_df', 
'BALL'  : 'BALL_df', 
'BAC'  : 'BAC_df', 
'BK'  : 'BK_df', 
'BBWI'  : 'BBWI_df', 
'BAX'  : 'BAX_df', 
'BDX'  : 'BDX_df', 
'BRK-B'  : 'BRK-B_df', #2/16/2010
'BBY'  : 'BBY_df', 
'BIO'  : 'BIO_df', 
'TECH'  : 'TECH_df', 
'BIIB'  : 'BIIB_df', 
'BLK'  : 'BLK_df', 
'BX'  : 'BX_df', 
'BA'  : 'BA_df', 
'BKNG'  : 'BKNG_df', 
'BWA'  : 'BWA_df', 
'BSX'  : 'BSX_df', 
'BMY'  : 'BMY_df', 
'AVGO'  : 'AVGO_df', 
'BR'  : 'BR_df', 
'BRO'  : 'BRO_df', 
'BF-B'  : 'BF.B_df', 
'BLDR'  : 'BLDR_df', #12/18/2023
'BG'  : 'BG_df', 
'BXP'  : 'BXP_df', 
'CDNS'  : 'CDNS_df', 
'CZR'  : 'CZR_df', 
'CPT'  : 'CPT_df', 
'CPB'  : 'CPB_df', 
'COF'  : 'COF_df', 
'CAH'  : 'CAH_df', 
'KMX'  : 'KMX_df', 
'CCL'  : 'CCL_df', 
'CARR'  : 'CARR_df', 
'CTLT'  : 'CTLT_df', 
'CAT'  : 'CAT_df', 
'CBOE'  : 'CBOE_df', 
'CBRE'  : 'CBRE_df', 
'CDW'  : 'CDW_df', 
'CE'  : 'CE_df', 
'COR'  : 'COR_df', 
'CNC'  : 'CNC_df', 
'CNP'  : 'CNP_df', 
'CPAY': 'CPAY_df', #added 06-20-2018
'CF'  : 'CF_df', 
'CHRW'  : 'CHRW_df', 
'CRL'  : 'CRL_df', 
'SCHW'  : 'SCHW_df', 
'CHTR'  : 'CHTR_df', 
'CVX'  : 'CVX_df', 
'CMG'  : 'CMG_df', 
'CB'  : 'CB_df', 
'CHD'  : 'CHD_df', 
'CI'  : 'CI_df', 
'CINF'  : 'CINF_df', 
'CTAS'  : 'CTAS_df', 
'CSCO'  : 'CSCO_df', 
'C'  : 'C_df', 
'CFG'  : 'CFG_df', 
'CLX'  : 'CLX_df', 
'CME'  : 'CME_df', 
'CMS'  : 'CMS_df', 
'KO'  : 'KO_df', 
'CTSH'  : 'CTSH_df', 
'CL'  : 'CL_df', 
'CMCSA'  : 'CMCSA_df', 
'CAG'  : 'CAG_df', 
'COP'  : 'COP_df', 
'ED'  : 'ED_df', 
'STZ'  : 'STZ_df', 
'CEG'  : 'CEG_df', 
'COO'  : 'COO_df', 
'CPRT'  : 'CPRT_df', 
'GLW'  : 'GLW_df', 
'CPAY'  : 'CPAY_df', 
'CTVA'  : 'CTVA_df', 
'CSGP'  : 'CSGP_df', 
'COST'  : 'COST_df', 
'CTRA'  : 'CTRA_df', 
'CRWD'  : 'CRWD_df', #added 6/24/2024
'CCI'  : 'CCI_df', 
'CSX'  : 'CSX_df', 
'CMI'  : 'CMI_df', 
'CVS'  : 'CVS_df', 
'DHR'  : 'DHR_df', 
'DRI'  : 'DRI_df', 
'DVA'  : 'DVA_df', 
'DAY'  : 'DAY_df', #added 9/20/2021
'DECK'  : 'DECK_df', #added 3/18/2024
'DE'  : 'DE_df', 
'DAL'  : 'DAL_df', 
'DVN'  : 'DVN_df', 
'DXCM'  : 'DXCM_df', 
'FANG'  : 'FANG_df', 
'DLR'  : 'DLR_df', 
'DFS'  : 'DFS_df', 
'DG'  : 'DG_df', 
'DLTR'  : 'DLTR_df', 
'D'  : 'D_df', 
'DPZ'  : 'DPZ_df', 
'DOC' : 'DOC_df', #added 3/31/2008
'DOV'  : 'DOV_df', 
'DOW'  : 'DOW_df', 
'DHI'  : 'DHI_df', 
'DTE'  : 'DTE_df', 
'DUK'  : 'DUK_df', 
'DD'  : 'DD_df', 
'EMN'  : 'EMN_df', 
'ETN'  : 'ETN_df', 
'EBAY'  : 'EBAY_df', 
'ECL'  : 'ECL_df', 
'EIX'  : 'EIX_df', 
'EW'  : 'EW_df', 
'EA'  : 'EA_df', 
'ELV'  : 'ELV_df', 
'LLY'  : 'LLY_df', 
'EMR'  : 'EMR_df', 
'ENPH'  : 'ENPH_df', 
'ETR'  : 'ETR_df', 
'EOG'  : 'EOG_df', 
'EPAM'  : 'EPAM_df', 
'EQT'  : 'EQT_df', 
'EFX'  : 'EFX_df', 
'EQIX'  : 'EQIX_df', 
'EQR'  : 'EQR_df', 
'ESS'  : 'ESS_df', 
'EL'  : 'EL_df', 
'ETSY'  : 'ETSY_df', 
'EG'  : 'EG_df', 
'EVRG'  : 'EVRG_df', 
'ES'  : 'ES_df', 
'EXC'  : 'EXC_df', 
'EXPE'  : 'EXPE_df', 
'EXPD'  : 'EXPD_df', 
'EXR'  : 'EXR_df', 
'XOM'  : 'XOM_df', 
'FFIV'  : 'FFIV_df', 
'FDS'  : 'FDS_df', 
'FICO'  : 'FICO_df', 
'FAST'  : 'FAST_df', 
'FRT'  : 'FRT_df', 
'FDX'  : 'FDX_df', 
'FIS'  : 'FIS_df', 
'FITB'  : 'FITB_df', 
'FSLR'  : 'FSLR_df', 
'FE'  : 'FE_df', 
'FI'  : 'FI_df', 
'FMC'  : 'FMC_df', 
'F'  : 'F_df', 
'FTNT'  : 'FTNT_df', 
'FTV'  : 'FTV_df', 
'FOXA'  : 'FOXA_df', 
'FOX'  : 'FOX_df', 
'BEN'  : 'BEN_df', 
'FCX'  : 'FCX_df', 
'GRMN'  : 'GRMN_df', 
'IT'  : 'IT_df', 
'GE'  : 'GE_df', 
'GEHC'  : 'GEHC_df', 
'GEV'  : 'GEV_df', #added 4/2/2024
'GEN'  : 'GEN_df', 
'GNRC'  : 'GNRC_df', 
'GD'  : 'GD_df', 
'GIS'  : 'GIS_df', 
'GM'  : 'GM_df', 
'GPC'  : 'GPC_df', 
'GILD'  : 'GILD_df', 
'GPN'  : 'GPN_df', 
'GL'  : 'GL_df', 
'GDDY'  : 'GDDY_df', #added 6/24/2024
'GS'  : 'GS_df', 
'HAL'  : 'HAL_df', 
'HIG'  : 'HIG_df', 
'HAS'  : 'HAS_df', 
'HCA'  : 'HCA_df', 
'DOC'  : 'DOC_df', 
'HSIC'  : 'HSIC_df', 
'HSY'  : 'HSY_df', 
'HES'  : 'HES_df', 
'HPE'  : 'HPE_df', 
'HLT'  : 'HLT_df', 
'HOLX'  : 'HOLX_df', 
'HD'  : 'HD_df', 
'HON'  : 'HON_df', 
'HRL'  : 'HRL_df', 
'HST'  : 'HST_df', 
'HWM'  : 'HWM_df', 
'HPQ'  : 'HPQ_df', 
'HUBB'  : 'HUBB_df', 
'HUM'  : 'HUM_df', 
'HBAN'  : 'HBAN_df', 
'HII'  : 'HII_df', 
'IBM'  : 'IBM_df', 
'IEX'  : 'IEX_df', 
'IDXX'  : 'IDXX_df', 
'ITW'  : 'ITW_df', 
'INCY'  : 'INCY_df', 
'IR'  : 'IR_df', 
'PODD'  : 'PODD_df', 
'INTC'  : 'INTC_df', 
'ICE'  : 'ICE_df', 
'IFF'  : 'IFF_df', 
'IP'  : 'IP_df', 
'IPG'  : 'IPG_df', 
'INTU'  : 'INTU_df', 
'ISRG'  : 'ISRG_df', 
'IVZ'  : 'IVZ_df', 
'INVH'  : 'INVH_df', 
'IQV'  : 'IQV_df', 
'IRM'  : 'IRM_df', 
'JBHT'  : 'JBHT_df', 
'JBL'  : 'JBL_df', #added 12/18/2023
'JKHY'  : 'JKHY_df', 
'J'  : 'J_df', 
'JNJ'  : 'JNJ_df', 
'JCI'  : 'JCI_df', 
'JPM'  : 'JPM_df', 
'JNPR'  : 'JNPR_df', 
'K'  : 'K_df', 
'KVUE'  : 'KVUE_df', 
'KDP'  : 'KDP_df', 
'KEY'  : 'KEY_df', 
'KEYS'  : 'KEYS_df', 
'KMB'  : 'KMB_df', 
'KIM'  : 'KIM_df', 
'KMI'  : 'KMI_df', 
'KKR'  : 'KKR_df', #added 6/24/2024
'KLAC'  : 'KLAC_df', 
'KHC'  : 'KHC_df', 
'KR'  : 'KR_df', 
'LHX'  : 'LHX_df', 
'LH'  : 'LH_df', 
'LRCX'  : 'LRCX_df', 
'LW'  : 'LW_df', 
'LVS'  : 'LVS_df', 
'LDOS'  : 'LDOS_df', 
'LEN'  : 'LEN_df', 
'LIN'  : 'LIN_df', 
'LYV'  : 'LYV_df', 
'LKQ'  : 'LKQ_df', 
'LMT'  : 'LMT_df', 
'L'  : 'L_df', 
'LOW'  : 'LOW_df', 
'LULU'  : 'LULU_df', 
'LYB'  : 'LYB_df', 
'MTB'  : 'MTB_df', 
'MRO'  : 'MRO_df', 
'MPC'  : 'MPC_df', 
'MKTX'  : 'MKTX_df', 
'MAR'  : 'MAR_df', 
'MMC'  : 'MMC_df', 
'MLM'  : 'MLM_df', 
'MAS'  : 'MAS_df', 
'MA'  : 'MA_df', 
'MTCH'  : 'MTCH_df', 
'MKC'  : 'MKC_df', 
'MCD'  : 'MCD_df', 
'MCK'  : 'MCK_df', 
'MDT'  : 'MDT_df', 
'MRK'  : 'MRK_df', 
'META'  : 'META_df', 
'MET'  : 'MET_df', 
'MTD'  : 'MTD_df', 
'MGM'  : 'MGM_df', 
'MCHP'  : 'MCHP_df', 
'MU'  : 'MU_df', 
'MSFT'  : 'MSFT_df', 
'MAA'  : 'MAA_df', 
'MRNA'  : 'MRNA_df', 
'MHK'  : 'MHK_df', 
'MOH'  : 'MOH_df', 
'TAP'  : 'TAP_df', 
'MDLZ'  : 'MDLZ_df', 
'MPWR'  : 'MPWR_df', 
'MNST'  : 'MNST_df', 
'MCO'  : 'MCO_df', 
'MS'  : 'MS_df', 
'MOS'  : 'MOS_df', 
'MSI'  : 'MSI_df', 
'MSCI'  : 'MSCI_df', 
'NDAQ'  : 'NDAQ_df', 
'NTAP'  : 'NTAP_df', 
'NFLX'  : 'NFLX_df', 
'NEM'  : 'NEM_df', 
'NWSA'  : 'NWSA_df', 
'NWS'  : 'NWS_df', 
'NEE'  : 'NEE_df', 
'NKE'  : 'NKE_df', 
'NI'  : 'NI_df', 
'NDSN'  : 'NDSN_df', 
'NSC'  : 'NSC_df', 
'NTRS'  : 'NTRS_df', 
'NOC'  : 'NOC_df', 
'NCLH'  : 'NCLH_df', 
'NRG'  : 'NRG_df', 
'NUE'  : 'NUE_df', 
'NVDA'  : 'NVDA_df', 
'NVR'  : 'NVR_df', 
'NXPI'  : 'NXPI_df', 
'ORLY'  : 'ORLY_df', 
'OXY'  : 'OXY_df', 
'ODFL'  : 'ODFL_df', 
'OMC'  : 'OMC_df', 
'ON'  : 'ON_df', 
'OKE'  : 'OKE_df', 
'ORCL'  : 'ORCL_df', 
'OTIS'  : 'OTIS_df', 
'PCAR'  : 'PCAR_df', 
'PKG'  : 'PKG_df', 
'PANW'  : 'PANW_df', 
'PARA'  : 'PARA_df', 
'PH'  : 'PH_df', 
'PAYX'  : 'PAYX_df', 
'PAYC'  : 'PAYC_df', 
'PYPL'  : 'PYPL_df', 
'PNR'  : 'PNR_df', 
'PEP'  : 'PEP_df', 
'PFE'  : 'PFE_df', 
'PCG'  : 'PCG_df', 
'PM'  : 'PM_df', 
'PSX'  : 'PSX_df', 
'PNW'  : 'PNW_df', 
'PNC'  : 'PNC_df', 
'POOL'  : 'POOL_df', 
'PPG'  : 'PPG_df', 
'PPL'  : 'PPL_df', 
'PFG'  : 'PFG_df', 
'PG'  : 'PG_df', 
'PGR'  : 'PGR_df', 
'PLD'  : 'PLD_df', 
'PRU'  : 'PRU_df', 
'PEG'  : 'PEG_df', 
'PTC'  : 'PTC_df', 
'PSA'  : 'PSA_df', 
'PHM'  : 'PHM_df', 
'QRVO'  : 'QRVO_df', 
'PWR'  : 'PWR_df', 
'QCOM'  : 'QCOM_df', 
'DGX'  : 'DGX_df', 
'RL'  : 'RL_df', 
'RJF'  : 'RJF_df', 
'RTX'  : 'RTX_df', 
'O'  : 'O_df', 
'REG'  : 'REG_df', 
'REGN'  : 'REGN_df', 
'RF'  : 'RF_df', 
'RSG'  : 'RSG_df', 
'RMD'  : 'RMD_df', 
'RVTY'  : 'RVTY_df', 
'ROK'  : 'ROK_df', 
'ROL'  : 'ROL_df', 
'ROP'  : 'ROP_df', 
'ROST'  : 'ROST_df', 
'RCL'  : 'RCL_df', 
'SPGI'  : 'SPGI_df', 
'CRM'  : 'CRM_df', 
'SBAC'  : 'SBAC_df', 
'SLB'  : 'SLB_df', 
'STX'  : 'STX_df', 
'SRE'  : 'SRE_df', 
'NOW'  : 'NOW_df', 
'SHW'  : 'SHW_df', 
'SPG'  : 'SPG_df', 
'SWKS'  : 'SWKS_df', 
'SJM'  : 'SJM_df', 
'SNA'  : 'SNA_df', 
'SOLV'  : 'SOLV_df', 
'SO'  : 'SO_df', 
'LUV'  : 'LUV_df', 
'SWK'  : 'SWK_df', 
'SW' : 'SW_df', #added 3/4/1957
'SBUX'  : 'SBUX_df', 
'STT'  : 'STT_df', 
'STLD'  : 'STLD_df', 
'STE'  : 'STE_df', 
'SYK'  : 'SYK_df', 
'SMCI'  : 'SMCI_df', 
'SYF'  : 'SYF_df', 
'SNPS'  : 'SNPS_df', 
'SYY'  : 'SYY_df', 
'TMUS'  : 'TMUS_df', 
'TROW'  : 'TROW_df', 
'TTWO'  : 'TTWO_df', 
'TPR'  : 'TPR_df', 
'TRGP'  : 'TRGP_df', 
'TGT'  : 'TGT_df', 
'TEL'  : 'TEL_df', 
'TDY'  : 'TDY_df', 
'TFX'  : 'TFX_df', 
'TER'  : 'TER_df', 
'TSLA'  : 'TSLA_df', 
'TXN'  : 'TXN_df', 
'TXT'  : 'TXT_df', 
'TMO'  : 'TMO_df', 
'TJX'  : 'TJX_df', 
'TSCO'  : 'TSCO_df', 
'TT'  : 'TT_df', 
'TDG'  : 'TDG_df', 
'TRV'  : 'TRV_df', 
'TRMB'  : 'TRMB_df', 
'TFC'  : 'TFC_df', 
'TYL'  : 'TYL_df', 
'TSN'  : 'TSN_df', 
'USB'  : 'USB_df', 
'UBER'  : 'UBER_df', #added 12/18/2023
'UDR'  : 'UDR_df', 
'ULTA'  : 'ULTA_df', 
'UNP'  : 'UNP_df', 
'UAL'  : 'UAL_df', 
'UPS'  : 'UPS_df', 
'URI'  : 'URI_df', 
'UNH'  : 'UNH_df', 
'UHS'  : 'UHS_df', 
'VLO'  : 'VLO_df', 
'VTR'  : 'VTR_df', 
'VLTO'  : 'VLTO_df', 
'VRSN'  : 'VRSN_df', 
'VRSK'  : 'VRSK_df', 
'VZ'  : 'VZ_df', 
'VRTX'  : 'VRTX_df', 
'VTRS'  : 'VTRS_df', 
'VICI'  : 'VICI_df', 
'V'  : 'V_df', 
'VST'  : 'VST_df', #added 5/8/2024
'VMC'  : 'VMC_df', 
'WRB'  : 'WRB_df', 
'GWW'  : 'GWW_df', 
'WAB'  : 'WAB_df', 
'WBA'  : 'WBA_df', 
'WMT'  : 'WMT_df', 
'DIS'  : 'DIS_df', 
'WBD'  : 'WBD_df', 
'WM'  : 'WM_df', 
'WAT'  : 'WAT_df', 
'WEC'  : 'WEC_df', 
'WFC'  : 'WFC_df', 
'WELL'  : 'WELL_df', 
'WST'  : 'WST_df', 
'WDC'  : 'WDC_df', 
'WRK'  : 'WRK_df', 
'WY'  : 'WY_df', 
'WMB'  : 'WMB_df', 
'WTW'  : 'WTW_df', 
'WYNN'  : 'WYNN_df', 
'XEL'  : 'XEL_df', 
'XYL'  : 'XYL_df', 
'YUM'  : 'YUM_df', 
'ZBRA'  : 'ZBRA_df', 
'ZBH'  : 'ZBH_df', 
'ZTS'  : 'ZTS_df'
}

# %%
sp500_df = df1

for k,v in spDict.items():
    try:
        v = pl.read_csv(f'stocks/{k}.csv')
        v = v.with_columns(Ticker=pl.lit(f'{k}'))
        sp500_df = pl.concat([sp500_df,v], rechunk=True) #new memory slab
    except:
        pass

# %%
try:
    sp500_df = sp500_df.with_columns(pl.col("Date").str.to_date())
except Exception as e:
    print(e)

print(sp500_df)

#print(sp500_df)
# Out:
# shape: (2_704_684, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬─────────┬────────┐
# │ Date       ┆ Open       ┆ High       ┆ Low        ┆ Close      ┆ Adj Close  ┆ Volume  ┆ Ticker │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---    │
# │ date       ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ i64     ┆ str    │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═════════╪════════╡
# │ 2000-01-03 ┆ 40.159908  ┆ 40.342808  ┆ 39.323788  ┆ 39.45443   ┆ 19.920654  ┆ 2599386 ┆ MMM    │
# │ 2000-01-04 ┆ 38.827339  ┆ 39.637333  ┆ 37.886707  ┆ 37.886707  ┆ 19.129105  ┆ 3245705 ┆ MMM    │
# │ 2000-01-05 ┆ 38.095737  ┆ 40.238293  ┆ 38.095737  ┆ 38.984116  ┆ 19.683186  ┆ 4424482 ┆ MMM    │
# │ 2000-01-06 ┆ 39.428303  ┆ 42.85117   ┆ 39.428303  ┆ 42.119564  ┆ 21.266291  ┆ 7147057 ┆ MMM    │
# ...

# %%
#sp500_df.write_csv("stocks/sp500.csv", separator=",") #WRITE THE WHOLE BIG SP500 TO DISK/FOLDER

# %%
sp500_df.shape
# Out:
# (2704684, 8)

# %%
ctx = pl.SQLContext(sp=sp500_df)

# %%
ctx.execute('''
select * from sp where Ticker = 'MSFT' 


''',
eager=True,
)
# Out:
# shape: (6_172, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬────────┐
# │ Date       ┆ Open       ┆ High       ┆ Low        ┆ Close      ┆ Adj Close  ┆ Volume   ┆ Ticker │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ ---    │
# │ date       ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ i64      ┆ str    │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪════════╡
# │ 2000-01-03 ┆ 58.6875    ┆ 59.3125    ┆ 56.0       ┆ 58.28125   ┆ 36.000629  ┆ 53228400 ┆ MSFT   │
# │ 2000-01-04 ┆ 56.78125   ┆ 58.5625    ┆ 56.125     ┆ 56.3125    ┆ 34.784527  ┆ 54119000 ┆ MSFT   │
# │ 2000-01-05 ┆ 55.5625    ┆ 58.1875    ┆ 54.6875    ┆ 56.90625   ┆ 35.151302  ┆ 64059600 ┆ MSFT   │
# │ 2000-01-06 ┆ 56.09375   ┆ 56.9375    ┆ 54.1875    ┆ 55.0       ┆ 33.97377   ┆ 54976600 ┆ MSFT   │
# ...

# %%
sp500_df.write_database(table_name="sp500Temp",

    connection="postgresql://postgres:test123@localhost:5432/x",
    #if_table_exists = "append",
    engine="adbc",
    #engine_options={"temporary": True},
)
# Out:
# 2704684

# %%
#!pip install adbc_driver_manager

# %%
#!pip install adbc-driver-postgresql pyarrow
