# %%
#pip install psycopg2-binary
import psycopg2
conn = psycopg2.connect("dbname=x user=postgres password=test123")

# %%
cursor = conn.cursor()
query = "SELECT * FROM public.econ"
cursor.execute(query)
record = cursor.fetchall()
for row in record:
    print(row)
# Out:
# (202311, 'United States', 25463, Decimal('4.90'), Decimal('5.50'), Decimal('3.70'), Decimal('3.90'), Decimal('-5.8'), Decimal('129.00'), Decimal('-3.70'), Decimal('334.23'))

# %%
    
import yfinance as yf
import time

#data = yf.download("BRK-B", start="2000-01-01", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
#data.to_csv("c:/proj/fintech/stocks/" + "BRK-B" + ".csv")

data2 = yf.download("GOOGL", start="2014-04-03", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data2.to_csv("c:/proj/fintech/stocks/" + "GOOGL" + ".csv")

data3 = yf.download("BRK-B", start="2010-02-16", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data3.to_csv("c:/proj/fintech/stocks/" + "BRK-B" + ".csv")

data4 = yf.download("BF-B", start="2000-01-01", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data4.to_csv("c:/proj/fintech/stocks/" + "BF-B" + ".csv")

data5 = yf.download("BLDR", start="2023-12-18", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data5.to_csv("c:/proj/fintech/stocks/" + "BLDR" + ".csv")

data6 = yf.download("CPAY", start="2018-06-20", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data6.to_csv("c:/proj/fintech/stocks/" + "CPAY" + ".csv")

data7 = yf.download("CRWD", start="2024-06-24", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data7.to_csv("c:/proj/fintech/stocks/" + "CRWD" + ".csv")

data8 = yf.download("DAY", start="2021-09-20", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data8.to_csv("c:/proj/fintech/stocks/" + "DAY" + ".csv")

data9 = yf.download("DECK", start="2024-03-18", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data9.to_csv("c:/proj/fintech/stocks/" + "DECK" + ".csv")

data10 = yf.download("DOC", start="2008-03-31", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data10.to_csv("c:/proj/fintech/stocks/" + "DOC" + ".csv")

data11 = yf.download("GEV", start="2024-04-02", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data11.to_csv("c:/proj/fintech/stocks/" + "GEV" + ".csv")

data12 = yf.download("GDDY", start="2024-06-24", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data12.to_csv("c:/proj/fintech/stocks/" + "GDDY" + ".csv")

data13 = yf.download("JBL", start="2023-12-18", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data13.to_csv("c:/proj/fintech/stocks/" + "JBL" + ".csv")

data14 = yf.download("KKR", start="2024-06-24", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data14.to_csv("c:/proj/fintech/stocks/" + "KKR" + ".csv")


data15 = yf.download("SW", start="2000-01-01", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data15.to_csv("c:/proj/fintech/stocks/" + "SW" + ".csv")

data16 = yf.download("UBER", start="2023-12-18", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data16.to_csv("c:/proj/fintech/stocks/" + "UBER" + ".csv")

data17 = yf.download("VST", start="2024-05-08", end= "2024-07-18")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
data17.to_csv("c:/proj/fintech/stocks/" + "VST" + ".csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
#SP 500 stocks
import yfinance as yf
import time

sp500 = [
    {'Symbol': 'MMM', 'Security': '3M'},
    {'Symbol': 'AOS', 'Security': 'A. O. Smith'},
    {'Symbol': 'ABT', 'Security': 'Abbott'},
    {'Symbol': 'ABBV', 'Security': 'AbbVie'},
    {'Symbol': 'ACN', 'Security': 'Accenture'},
    {'Symbol': 'ADBE', 'Security': 'Adobe Inc.'},
    {'Symbol': 'AMD', 'Security': 'Advanced Micro Devices'},
    {'Symbol': 'AES', 'Security': 'AES Corporation'},
    {'Symbol': 'AFL', 'Security': 'Aflac'},
    {'Symbol': 'A', 'Security': 'Agilent Technologies'},
    {'Symbol': 'APD', 'Security': 'Air Products and Chemicals'},
    {'Symbol': 'ABNB', 'Security': 'Airbnb'},
    {'Symbol': 'AKAM', 'Security': 'Akamai'},
    #{'Symbol': 'ALK', 'Security': 'Alaska Air Group'}, #REMOVED IN 2024
    {'Symbol': 'ALB', 'Security': 'Albemarle Corporation'},
    {'Symbol': 'ARE', 'Security': 'Alexandria Real Estate Equities'},
    {'Symbol': 'ALGN', 'Security': 'Align Technology'},
    {'Symbol': 'ALLE', 'Security': 'Allegion'},
    {'Symbol': 'LNT', 'Security': 'Alliant Energy'},
    {'Symbol': 'ALL', 'Security': 'Allstate'},
    #{'Symbol': 'GOOGL', 'Security': 'Alphabet Inc. (Class A)'},
    {'Symbol': 'GOOG', 'Security': 'Alphabet Inc. (Class C)'},
    {'Symbol': 'MO', 'Security': 'Altria'},
    {'Symbol': 'AMZN', 'Security': 'Amazon'},
    {'Symbol': 'AMCR', 'Security': 'Amcor'},
    {'Symbol': 'AEE', 'Security': 'Ameren'},
    {'Symbol': 'AAL', 'Security': 'American Airlines Group'},
    {'Symbol': 'AEP', 'Security': 'American Electric Power'},
    {'Symbol': 'AXP', 'Security': 'American Express'},
    {'Symbol': 'AIG', 'Security': 'American International Group'},
    {'Symbol': 'AMT', 'Security': 'American Tower'},
    {'Symbol': 'AWK', 'Security': 'American Water Works'},
    {'Symbol': 'AMP', 'Security': 'Ameriprise Financial'},
    {'Symbol': 'AME', 'Security': 'Ametek'},
    {'Symbol': 'AMGN', 'Security': 'Amgen'},
    {'Symbol': 'APH', 'Security': 'Amphenol'},
    {'Symbol': 'ADI', 'Security': 'Analog Devices'},
    {'Symbol': 'ANSS', 'Security': 'Ansys'},
    {'Symbol': 'AON', 'Security': 'Aon'},
    {'Symbol': 'APA', 'Security': 'APA Corporation'},
    {'Symbol': 'AAPL', 'Security': 'Apple Inc.'},
    {'Symbol': 'AMAT', 'Security': 'Applied Materials'},
    {'Symbol': 'APTV', 'Security': 'Aptiv'},
    {'Symbol': 'ACGL', 'Security': 'Arch Capital Group'},
    {'Symbol': 'ADM', 'Security': 'Archer-Daniels-Midland'},
    {'Symbol': 'ANET', 'Security': 'Arista Networks'},
    {'Symbol': 'AJG', 'Security': 'Arthur J. Gallagher & Co.'},
    {'Symbol': 'AIZ', 'Security': 'Assurant'},
    {'Symbol': 'T', 'Security': 'AT&T'},
    {'Symbol': 'ATO', 'Security': 'Atmos Energy'},
    {'Symbol': 'ADSK', 'Security': 'Autodesk'},
    {'Symbol': 'ADP', 'Security': 'Automated Data Processing'},
    {'Symbol': 'AZO', 'Security': 'AutoZone'},
    {'Symbol': 'AVB', 'Security': 'AvalonBay Communities'},
    {'Symbol': 'AVY', 'Security': 'Avery Dennison'},
    {'Symbol': 'AXON', 'Security': 'Axon Enterprise'},
    {'Symbol': 'BKR', 'Security': 'Baker Hughes'},
    {'Symbol': 'BALL', 'Security': 'Ball Corporation'},
    {'Symbol': 'BAC', 'Security': 'Bank of America'},
    {'Symbol': 'BK', 'Security': 'Bank of New York Mellon'},
    {'Symbol': 'BBWI', 'Security': 'Bath & Body Works, Inc.'},
    {'Symbol': 'BAX', 'Security': 'Baxter International'},
    {'Symbol': 'BDX', 'Security': 'Becton Dickinson'},
    #{'Symbol': 'BRK-B', 'Security': 'Berkshire Hathaway'},
    {'Symbol': 'BBY', 'Security': 'Best Buy'},
    {'Symbol': 'BIO', 'Security': 'Bio-Rad'},
    {'Symbol': 'TECH', 'Security': 'Bio-Techne'},
    {'Symbol': 'BIIB', 'Security': 'Biogen'},
    #{'Symbol': 'BLDR', 'Security': 'Builder'},
    {'Symbol': 'BLK', 'Security': 'BlackRock'},
    {'Symbol': 'BX', 'Security': 'Blackstone'},
    {'Symbol': 'BA', 'Security': 'Boeing'},
    {'Symbol': 'BKNG', 'Security': 'Booking Holdings'},
    {'Symbol': 'BWA', 'Security': 'BorgWarner'},
    {'Symbol': 'BXP', 'Security': 'Boston Properties'},
    {'Symbol': 'BSX', 'Security': 'Boston Scientific'},
    {'Symbol': 'BMY', 'Security': 'Bristol Myers Squibb'},
    {'Symbol': 'AVGO', 'Security': 'Broadcom Inc.'},
    {'Symbol': 'BR', 'Security': 'Broadridge Financial Solutions'},
    {'Symbol': 'BRO', 'Security': 'Brown & Brown'},
    #{'Symbol': 'BF-B', 'Security': 'Brown–Forman'},
    {'Symbol': 'BG', 'Security': 'Bunge Global SA'},
    {'Symbol': 'CDNS', 'Security': 'Cadence Design Systems'},
    {'Symbol': 'CZR', 'Security': 'Caesars Entertainment'},
    {'Symbol': 'CPT', 'Security': 'Camden Property Trust'},
    {'Symbol': 'CPB', 'Security': 'Campbell Soup Company'},
    {'Symbol': 'COF', 'Security': 'Capital One'},
    {'Symbol': 'CAH', 'Security': 'Cardinal Health'},
    {'Symbol': 'KMX', 'Security': 'CarMax'},
    {'Symbol': 'CCL', 'Security': 'Carnival'},
    {'Symbol': 'CARR', 'Security': 'Carrier Global'},
    {'Symbol': 'CTLT', 'Security': 'Catalent'},
    {'Symbol': 'CAT', 'Security': 'Caterpillar Inc.'},
    {'Symbol': 'CBOE', 'Security': 'Cboe Global Markets'},
    {'Symbol': 'CBRE', 'Security': 'CBRE Group'},
    {'Symbol': 'CDW', 'Security': 'CDW'},
    {'Symbol': 'CE', 'Security': 'Celanese'},
    {'Symbol': 'COR', 'Security': 'Cencora'},
    {'Symbol': 'CNC', 'Security': 'Centene Corporation'},
    {'Symbol': 'CNP', 'Security': 'CenterPoint Energy'},
    #{'Symbol': 'CPAY', 'Security': 'Ceridian'},
    {'Symbol': 'CF', 'Security': 'CF Industries'},
    {'Symbol': 'CHRW', 'Security': 'CH Robinson'},
    {'Symbol': 'CRL', 'Security': 'Charles River Laboratories'},
    {'Symbol': 'SCHW', 'Security': 'Charles Schwab Corporation'},
    {'Symbol': 'CHTR', 'Security': 'Charter Communications'},
    {'Symbol': 'CVX', 'Security': 'Chevron Corporation'},
    {'Symbol': 'CMG', 'Security': 'Chipotle Mexican Grill'},
    {'Symbol': 'CB', 'Security': 'Chubb Limited'},
    {'Symbol': 'CHD', 'Security': 'Church & Dwight'},
    {'Symbol': 'CI', 'Security': 'Cigna'},
    {'Symbol': 'CINF', 'Security': 'Cincinnati Financial'},
    {'Symbol': 'CTAS', 'Security': 'Cintas'},
    {'Symbol': 'CSCO', 'Security': 'Cisco'},
    #{'Symbol': 'CRWD', 'Security': 'CRWD'},
    {'Symbol': 'C', 'Security': 'Citigroup'},
    {'Symbol': 'CFG', 'Security': 'Citizens Financial Group'},
    {'Symbol': 'CLX', 'Security': 'Clorox'},
    {'Symbol': 'CME', 'Security': 'CME Group'},
    {'Symbol': 'CMS', 'Security': 'CMS Energy'},
    {'Symbol': 'KO', 'Security': 'Coca-Cola Company (The)'},
    {'Symbol': 'CTSH', 'Security': 'Cognizant'},
    {'Symbol': 'CL', 'Security': 'Colgate-Palmolive'},
    {'Symbol': 'CMCSA', 'Security': 'Comcast'},
    {'Symbol': 'CMA', 'Security': 'Comerica'},
    {'Symbol': 'CAG', 'Security': 'Conagra Brands'},
    {'Symbol': 'COP', 'Security': 'ConocoPhillips'},
    {'Symbol': 'ED', 'Security': 'Consolidated Edison'},
    {'Symbol': 'STZ', 'Security': 'Constellation Brands'},
    {'Symbol': 'CEG', 'Security': 'Constellation Energy'},
    {'Symbol': 'COO', 'Security': 'CooperCompanies'},
    {'Symbol': 'CPRT', 'Security': 'Copart'},
    {'Symbol': 'GLW', 'Security': 'Corning Inc.'},
    {'Symbol': 'CTVA', 'Security': 'Corteva'},
    {'Symbol': 'CSGP', 'Security': 'CoStar Group'},
    {'Symbol': 'COST', 'Security': 'Costco'},
    {'Symbol': 'CTRA', 'Security': 'Coterra'},
    {'Symbol': 'CCI', 'Security': 'Crown Castle'},
    {'Symbol': 'CSX', 'Security': 'CSX'},
    {'Symbol': 'CMI', 'Security': 'Cummins'},
    {'Symbol': 'CVS', 'Security': 'CVS Health'},
    {'Symbol': 'DHR', 'Security': 'Danaher Corporation'},
    {'Symbol': 'DRI', 'Security': 'Darden Restaurants'},
    {'Symbol': 'DVA', 'Security': 'DaVita Inc.'},
    {'Symbol': 'DE', 'Security': 'John Deere'},
    #{'Symbol': 'DECK', 'Security': 'DECK'},
    {'Symbol': 'DAL', 'Security': 'Delta Air Lines'},
    #{'Symbol': 'DAY', 'Security': 'DAY'},
    {'Symbol': 'XRAY', 'Security': 'Dentsply Sirona'},
    {'Symbol': 'DVN', 'Security': 'Devon Energy'},
    {'Symbol': 'DXCM', 'Security': 'Dexcom'},
    {'Symbol': 'FANG', 'Security': 'Diamondback Energy'},
    {'Symbol': 'DLR', 'Security': 'Digital Realty'},
    {'Symbol': 'DFS', 'Security': 'Discover Financial'},
    {'Symbol': 'DG', 'Security': 'Dollar General'},
    {'Symbol': 'DLTR', 'Security': 'Dollar Tree'},
    {'Symbol': 'D', 'Security': 'Dominion Energy'},
    {'Symbol': 'DPZ', 'Security': 'Dominos'},
    #{'Symbol': 'DOC', 'Security': 'DOC'},
    {'Symbol': 'DOV', 'Security': 'Dover Corporation'},
    {'Symbol': 'DOW', 'Security': 'Dow Inc.'},
    {'Symbol': 'DHI', 'Security': 'DR Horton'},
    {'Symbol': 'DTE', 'Security': 'DTE Energy'},
    {'Symbol': 'DUK', 'Security': 'Duke Energy'},
    {'Symbol': 'DD', 'Security': 'DuPont'},
    {'Symbol': 'EMN', 'Security': 'Eastman Chemical Company'},
    {'Symbol': 'ETN', 'Security': 'Eaton Corporation'},
    {'Symbol': 'EBAY', 'Security': 'eBay'},
    {'Symbol': 'ECL', 'Security': 'Ecolab'},
    {'Symbol': 'EIX', 'Security': 'Edison International'},
    {'Symbol': 'EW', 'Security': 'Edwards Lifesciences'},
    {'Symbol': 'EA', 'Security': 'Electronic Arts'},
    {'Symbol': 'ELV', 'Security': 'Elevance Health'},
    {'Symbol': 'LLY', 'Security': 'Eli Lilly and Company'},
    {'Symbol': 'EMR', 'Security': 'Emerson Electric'},
    {'Symbol': 'ENPH', 'Security': 'Enphase'},
    {'Symbol': 'ETR', 'Security': 'Entergy'},
    {'Symbol': 'EOG', 'Security': 'EOG Resources'},
    {'Symbol': 'EPAM', 'Security': 'EPAM Systems'},
    {'Symbol': 'EQT', 'Security': 'EQT'},
    {'Symbol': 'EFX', 'Security': 'Equifax'},
    {'Symbol': 'EQIX', 'Security': 'Equinix'},
    {'Symbol': 'EQR', 'Security': 'Equity Residential'},
    {'Symbol': 'ESS', 'Security': 'Essex Property Trust'},
    {'Symbol': 'EL', 'Security': 'Estée Lauder Companies (The)'},
    {'Symbol': 'ETSY', 'Security': 'Etsy'},
    {'Symbol': 'EG', 'Security': 'Everest Re'},
    {'Symbol': 'EVRG', 'Security': 'Evergy'},
    {'Symbol': 'ES', 'Security': 'Eversource'},
    {'Symbol': 'EXC', 'Security': 'Exelon'},
    {'Symbol': 'EXPE', 'Security': 'Expedia Group'},
    {'Symbol': 'EXPD', 'Security': 'Expeditors International'},
    {'Symbol': 'EXR', 'Security': 'Extra Space Storage'},
    {'Symbol': 'XOM', 'Security': 'ExxonMobil'},
    {'Symbol': 'FFIV', 'Security': 'F5, Inc.'},
    {'Symbol': 'FDS', 'Security': 'FactSet'},
    {'Symbol': 'FICO', 'Security': 'Fair Isaac'},
    {'Symbol': 'FAST', 'Security': 'Fastenal'},
    {'Symbol': 'FRT', 'Security': 'Federal Realty'},
    {'Symbol': 'FDX', 'Security': 'FedEx'},
    {'Symbol': 'FIS', 'Security': 'Fidelity National Information Services'},
    {'Symbol': 'FITB', 'Security': 'Fifth Third Bank'},
    {'Symbol': 'FSLR', 'Security': 'First Solar'},
    {'Symbol': 'FE', 'Security': 'FirstEnergy'},
    {'Symbol': 'FI', 'Security': 'Fiserv'},
    #{'Symbol': 'FLT', 'Security': 'Fleetcor'}, #REMOVED
    {'Symbol': 'FMC', 'Security': 'FMC Corporation'},
    {'Symbol': 'F', 'Security': 'Ford Motor Company'},
    {'Symbol': 'FTNT', 'Security': 'Fortinet'},
    {'Symbol': 'FTV', 'Security': 'Fortive'},
    {'Symbol': 'FOXA', 'Security': 'Fox Corporation (Class A)'},
    {'Symbol': 'FOX', 'Security': 'Fox Corporation (Class B)'},
    {'Symbol': 'BEN', 'Security': 'Franklin Templeton'},
    {'Symbol': 'FCX', 'Security': 'Freeport-McMoRan'},
    {'Symbol': 'GRMN', 'Security': 'Garmin'},
    {'Symbol': 'IT', 'Security': 'Gartner'},
    {'Symbol': 'GEHC', 'Security': 'GE HealthCare'},
    {'Symbol': 'GEN', 'Security': 'Gen Digital'},
    #{'Symbol': 'GEV', 'Security': 'GEV'},
    {'Symbol': 'GNRC', 'Security': 'Generac'},
    {'Symbol': 'GD', 'Security': 'General Dynamics'},
    #{'Symbol': 'GDDY', 'Security': 'GO DADDY'},
    {'Symbol': 'GE', 'Security': 'General Electric'},
    {'Symbol': 'GIS', 'Security': 'General Mills'},
    {'Symbol': 'GM', 'Security': 'General Motors'},
    {'Symbol': 'GPC', 'Security': 'Genuine Parts Company'},
    {'Symbol': 'GILD', 'Security': 'Gilead Sciences'},
    {'Symbol': 'GPN', 'Security': 'Global Payments'},
    {'Symbol': 'GL', 'Security': 'Globe Life'},
    {'Symbol': 'GS', 'Security': 'Goldman Sachs'},
    {'Symbol': 'HAL', 'Security': 'Halliburton'},
    {'Symbol': 'HIG', 'Security': 'Hartford (The)'},
    {'Symbol': 'HAS', 'Security': 'Hasbro'},
    {'Symbol': 'HCA', 'Security': 'HCA Healthcare'},
    {'Symbol': 'PEAK', 'Security': 'Healthpeak'},
    {'Symbol': 'HSIC', 'Security': 'Henry Schein'},
    {'Symbol': 'HSY', 'Security': 'Hershey\'s'},
    {'Symbol': 'HES', 'Security': 'Hess Corporation'},
    {'Symbol': 'HPE', 'Security': 'Hewlett Packard Enterprise'},
    {'Symbol': 'HLT', 'Security': 'Hilton Worldwide'},
    {'Symbol': 'HOLX', 'Security': 'Hologic'},
    {'Symbol': 'HD', 'Security': 'Home Depot (The)'},
    {'Symbol': 'HON', 'Security': 'Honeywell'},
    {'Symbol': 'HRL', 'Security': 'Hormel Foods'},
    {'Symbol': 'HST', 'Security': 'Host Hotels & Resorts'},
    {'Symbol': 'HWM', 'Security': 'Howmet Aerospace'},
    {'Symbol': 'HPQ', 'Security': 'HP Inc.'},
    {'Symbol': 'HUBB', 'Security': 'Hubbell Incorporated'},
    {'Symbol': 'HUM', 'Security': 'Humana'},
    {'Symbol': 'HBAN', 'Security': 'Huntington Bancshares'},
    {'Symbol': 'HII', 'Security': 'Huntington Ingalls Industries'},
    {'Symbol': 'IBM', 'Security': 'IBM'},
    {'Symbol': 'IEX', 'Security': 'IDEX Corporation'},
    {'Symbol': 'IDXX', 'Security': 'Idexx Laboratories'},
    {'Symbol': 'ITW', 'Security': 'Illinois Tool Works'},
    {'Symbol': 'ILMN', 'Security': 'Illumina'},
    {'Symbol': 'INCY', 'Security': 'Incyte'},
    {'Symbol': 'IR', 'Security': 'Ingersoll Rand'},
    {'Symbol': 'PODD', 'Security': 'Insulet'},
    {'Symbol': 'INTC', 'Security': 'Intel'},
    {'Symbol': 'ICE', 'Security': 'Intercontinental Exchange'},
    {'Symbol': 'IFF', 'Security': 'International Flavors & Fragrances'},
    {'Symbol': 'IP', 'Security': 'International Paper'},
    {'Symbol': 'IPG', 'Security': 'Interpublic Group of Companies (The)'},
    {'Symbol': 'INTU', 'Security': 'Intuit'},
    {'Symbol': 'ISRG', 'Security': 'Intuitive Surgical'},
    {'Symbol': 'IVZ', 'Security': 'Invesco'},
    {'Symbol': 'INVH', 'Security': 'Invitation Homes'},
    {'Symbol': 'IQV', 'Security': 'IQVIA'},
    {'Symbol': 'IRM', 'Security': 'Iron Mountain'},
    {'Symbol': 'JBHT', 'Security': 'J.B. Hunt'},
    {'Symbol': 'JKHY', 'Security': 'Jack Henry & Associates'},
    {'Symbol': 'J', 'Security': 'Jacobs Solutions'},
    #{'Symbol': 'JBL', 'Security': 'JBL'},
    {'Symbol': 'JNJ', 'Security': 'Johnson & Johnson'},
    {'Symbol': 'JCI', 'Security': 'Johnson Controls'},
    {'Symbol': 'JPM', 'Security': 'JPMorgan Chase'},
    {'Symbol': 'JNPR', 'Security': 'Juniper Networks'},
    {'Symbol': 'K', 'Security': 'Kellanova'},
    {'Symbol': 'KVUE', 'Security': 'Kenvue'},
    {'Symbol': 'KDP', 'Security': 'Keurig Dr Pepper'},
    {'Symbol': 'KEY', 'Security': 'KeyCorp'},
    {'Symbol': 'KEYS', 'Security': 'Keysight'},
    {'Symbol': 'KMB', 'Security': 'Kimberly-Clark'},
    {'Symbol': 'KIM', 'Security': 'Kimco Realty'},
    {'Symbol': 'KMI', 'Security': 'Kinder Morgan'},
    {'Symbol': 'KLAC', 'Security': 'KLA Corporation'},
    {'Symbol': 'KHC', 'Security': 'Kraft Heinz'},
    #{'Symbol': 'KKR', 'Security': 'KKR'},
    {'Symbol': 'KR', 'Security': 'Kroger'},
    {'Symbol': 'LHX', 'Security': 'L3Harris'},
    {'Symbol': 'LH', 'Security': 'LabCorp'},
    {'Symbol': 'LRCX', 'Security': 'Lam Research'},
    {'Symbol': 'LW', 'Security': 'Lamb Weston'},
    {'Symbol': 'LVS', 'Security': 'Las Vegas Sands'},
    {'Symbol': 'LDOS', 'Security': 'Leidos'},
    {'Symbol': 'LEN', 'Security': 'Lennar'},
    {'Symbol': 'LIN', 'Security': 'Linde plc'},
    {'Symbol': 'LYV', 'Security': 'Live Nation Entertainment'},
    {'Symbol': 'LKQ', 'Security': 'LKQ Corporation'},
    {'Symbol': 'LMT', 'Security': 'Lockheed Martin'},
    {'Symbol': 'L', 'Security': 'Loews Corporation'},
    {'Symbol': 'LOW', 'Security': 'Lowe\'s'},
    {'Symbol': 'LULU', 'Security': 'Lululemon Athletica'},
    {'Symbol': 'LYB', 'Security': 'LyondellBasell'},
    {'Symbol': 'MTB', 'Security': 'M&T Bank'},
    {'Symbol': 'MRO', 'Security': 'Marathon Oil'},
    {'Symbol': 'MPC', 'Security': 'Marathon Petroleum'},
    {'Symbol': 'MKTX', 'Security': 'MarketAxess'},
    {'Symbol': 'MAR', 'Security': 'Marriott International'},
    {'Symbol': 'MMC', 'Security': 'Marsh McLennan'},
    {'Symbol': 'MLM', 'Security': 'Martin Marietta Materials'},
    {'Symbol': 'MAS', 'Security': 'Masco'},
    {'Symbol': 'MA', 'Security': 'Mastercard'},
    {'Symbol': 'MTCH', 'Security': 'Match Group'},
    {'Symbol': 'MKC', 'Security': 'McCormick & Company'},
    {'Symbol': 'MCD', 'Security': 'McDonald\'s'},
    {'Symbol': 'MCK', 'Security': 'McKesson'},
    {'Symbol': 'MDT', 'Security': 'Medtronic'},
    {'Symbol': 'MRK', 'Security': 'Merck & Co.'},
    {'Symbol': 'META', 'Security': 'Meta Platforms'},
    {'Symbol': 'MET', 'Security': 'MetLife'},
    {'Symbol': 'MTD', 'Security': 'Mettler Toledo'},
    {'Symbol': 'MGM', 'Security': 'MGM Resorts'},
    {'Symbol': 'MCHP', 'Security': 'Microchip Technology'},
    {'Symbol': 'MU', 'Security': 'Micron Technology'},
    {'Symbol': 'MSFT', 'Security': 'Microsoft'},
    {'Symbol': 'MAA', 'Security': 'Mid-America Apartment Communities'},
    {'Symbol': 'MRNA', 'Security': 'Moderna'},
    {'Symbol': 'MHK', 'Security': 'Mohawk Industries'},
    {'Symbol': 'MOH', 'Security': 'Molina Healthcare'},
    {'Symbol': 'TAP', 'Security': 'Molson Coors Beverage Company'},
    {'Symbol': 'MDLZ', 'Security': 'Mondelez International'},
    {'Symbol': 'MPWR', 'Security': 'Monolithic Power Systems'},
    {'Symbol': 'MNST', 'Security': 'Monster Beverage'},
    {'Symbol': 'MCO', 'Security': 'Moody\'s Corporation'},
    {'Symbol': 'MS', 'Security': 'Morgan Stanley'},
    {'Symbol': 'MOS', 'Security': 'Mosaic Company (The)'},
    {'Symbol': 'MSI', 'Security': 'Motorola Solutions'},
    {'Symbol': 'MSCI', 'Security': 'MSCI'},
    {'Symbol': 'NDAQ', 'Security': 'Nasdaq, Inc.'},
    {'Symbol': 'NTAP', 'Security': 'NetApp'},
    {'Symbol': 'NFLX', 'Security': 'Netflix'},
    {'Symbol': 'NEM', 'Security': 'Newmont'},
    {'Symbol': 'NWSA', 'Security': 'News Corp (Class A)'},
    {'Symbol': 'NWS', 'Security': 'News Corp (Class B)'},
    {'Symbol': 'NEE', 'Security': 'NextEra Energy'},
    {'Symbol': 'NKE', 'Security': 'Nike, Inc.'},
    {'Symbol': 'NI', 'Security': 'NiSource'},
    {'Symbol': 'NDSN', 'Security': 'Nordson Corporation'},
    {'Symbol': 'NSC', 'Security': 'Norfolk Southern Railway'},
    {'Symbol': 'NTRS', 'Security': 'Northern Trust'},
    {'Symbol': 'NOC', 'Security': 'Northrop Grumman'},
    {'Symbol': 'NCLH', 'Security': 'Norwegian Cruise Line Holdings'},
    {'Symbol': 'NRG', 'Security': 'NRG Energy'},
    {'Symbol': 'NUE', 'Security': 'Nucor'},
    {'Symbol': 'NVDA', 'Security': 'Nvidia'},
    {'Symbol': 'NVR', 'Security': 'NVR, Inc.'},
    {'Symbol': 'NXPI', 'Security': 'NXP Semiconductors'},
    {'Symbol': 'ORLY', 'Security': 'O\'Reilly Auto Parts'},
    {'Symbol': 'OXY', 'Security': 'Occidental Petroleum'},
    {'Symbol': 'ODFL', 'Security': 'Old Dominion'},
    {'Symbol': 'OMC', 'Security': 'Omnicom Group'},
    {'Symbol': 'ON', 'Security': 'ON Semiconductor'},
    {'Symbol': 'OKE', 'Security': 'ONEOK'},
    {'Symbol': 'ORCL', 'Security': 'Oracle Corporation'},
    {'Symbol': 'OTIS', 'Security': 'Otis Worldwide'},
    {'Symbol': 'PCAR', 'Security': 'Paccar'},
    {'Symbol': 'PKG', 'Security': 'Packaging Corporation of America'},
    {'Symbol': 'PANW', 'Security': 'Palo Alto Networks'},
    {'Symbol': 'PARA', 'Security': 'Paramount Global'},
    {'Symbol': 'PH', 'Security': 'Parker Hannifin'},
    {'Symbol': 'PAYX', 'Security': 'Paychex'},
    {'Symbol': 'PAYC', 'Security': 'Paycom'},
    {'Symbol': 'PYPL', 'Security': 'PayPal'},
    {'Symbol': 'PNR', 'Security': 'Pentair'},
    {'Symbol': 'PEP', 'Security': 'PepsiCo'},
    {'Symbol': 'PFE', 'Security': 'Pfizer'},
    {'Symbol': 'PCG', 'Security': 'PG&E Corporation'},
    {'Symbol': 'PM', 'Security': 'Philip Morris International'},
    {'Symbol': 'PSX', 'Security': 'Phillips 66'},
    {'Symbol': 'PNW', 'Security': 'Pinnacle West'},
    {'Symbol': 'PXD', 'Security': 'Pioneer Natural Resources'},
    {'Symbol': 'PNC', 'Security': 'PNC Financial Services'},
    {'Symbol': 'POOL', 'Security': 'Pool Corporation'},
    {'Symbol': 'PPG', 'Security': 'PPG Industries'},
    {'Symbol': 'PPL', 'Security': 'PPL Corporation'},
    {'Symbol': 'PFG', 'Security': 'Principal Financial Group'},
    {'Symbol': 'PG', 'Security': 'Procter & Gamble'},
    {'Symbol': 'PGR', 'Security': 'Progressive Corporation'},
    {'Symbol': 'PLD', 'Security': 'Prologis'},
    {'Symbol': 'PRU', 'Security': 'Prudential Financial'},
    {'Symbol': 'PEG', 'Security': 'Public Service Enterprise Group'},
    {'Symbol': 'PTC', 'Security': 'PTC'},
    {'Symbol': 'PSA', 'Security': 'Public Storage'},
    {'Symbol': 'PHM', 'Security': 'PulteGroup'},
    {'Symbol': 'QRVO', 'Security': 'Qorvo'},
    {'Symbol': 'PWR', 'Security': 'Quanta Services'},
    {'Symbol': 'QCOM', 'Security': 'Qualcomm'},
    {'Symbol': 'DGX', 'Security': 'Quest Diagnostics'},
    {'Symbol': 'RL', 'Security': 'Ralph Lauren Corporation'},
    {'Symbol': 'RJF', 'Security': 'Raymond James'},
    {'Symbol': 'RTX', 'Security': 'RTX Corporation'},
    {'Symbol': 'O', 'Security': 'Realty Income'},
    {'Symbol': 'REG', 'Security': 'Regency Centers'},
    {'Symbol': 'REGN', 'Security': 'Regeneron'},
    {'Symbol': 'RF', 'Security': 'Regions Financial Corporation'},
    {'Symbol': 'RSG', 'Security': 'Republic Services'},
    {'Symbol': 'RMD', 'Security': 'ResMed'},
    {'Symbol': 'RVTY', 'Security': 'Revvity'},
    {'Symbol': 'RHI', 'Security': 'Robert Half'},
    {'Symbol': 'ROK', 'Security': 'Rockwell Automation'},
    {'Symbol': 'ROL', 'Security': 'Rollins, Inc.'},
    {'Symbol': 'ROP', 'Security': 'Roper Technologies'},
    {'Symbol': 'ROST', 'Security': 'Ross Stores'},
    {'Symbol': 'RCL', 'Security': 'Royal Caribbean Group'},
    {'Symbol': 'SPGI', 'Security': 'S&P Global'},
    {'Symbol': 'CRM', 'Security': 'Salesforce'},
    {'Symbol': 'SBAC', 'Security': 'SBA Communications'},
    {'Symbol': 'SLB', 'Security': 'Schlumberger'},
    {'Symbol': 'STX', 'Security': 'Seagate Technology'},
    {'Symbol': 'SEE', 'Security': 'Sealed Air'},
    {'Symbol': 'SRE', 'Security': 'Sempra Energy'},
    {'Symbol': 'NOW', 'Security': 'ServiceNow'},
    {'Symbol': 'SHW', 'Security': 'Sherwin-Williams'},
    {'Symbol': 'SPG', 'Security': 'Simon Property Group'},
    {'Symbol': 'SWKS', 'Security': 'Skyworks Solutions'},
    #{'Symbol': 'SW', 'Security': 'SW'},
    {'Symbol': 'SJM', 'Security': 'J.M. Smucker Company (The)'},
    {'Symbol': 'SNA', 'Security': 'Snap-on'},
    {'Symbol': 'SEDG', 'Security': 'SolarEdge'},
    {'Symbol': 'SO', 'Security': 'Southern Company'},
    {'Symbol': 'LUV', 'Security': 'Southwest Airlines'},
    {'Symbol': 'SWK', 'Security': 'Stanley Black & Decker'},
    {'Symbol': 'SBUX', 'Security': 'Starbucks'},
    {'Symbol': 'STT', 'Security': 'State Street Corporation'},
    {'Symbol': 'STLD', 'Security': 'Steel Dynamics'},
    {'Symbol': 'STE', 'Security': 'Steris'},
    {'Symbol': 'SYK', 'Security': 'Stryker Corporation'},
    {'Symbol': 'SYF', 'Security': 'Synchrony Financial'},
    {'Symbol': 'SNPS', 'Security': 'Synopsys'},
    {'Symbol': 'SYY', 'Security': 'Sysco'},
    {'Symbol': 'TMUS', 'Security': 'T-Mobile US'},
    {'Symbol': 'TROW', 'Security': 'T. Rowe Price'},
    {'Symbol': 'TTWO', 'Security': 'Take-Two Interactive'},
    {'Symbol': 'TPR', 'Security': 'Tapestry, Inc.'},
    {'Symbol': 'TRGP', 'Security': 'Targa Resources'},
    {'Symbol': 'TGT', 'Security': 'Target Corporation'},
    {'Symbol': 'TEL', 'Security': 'TE Connectivity'},
    {'Symbol': 'TDY', 'Security': 'Teledyne Technologies'},
    {'Symbol': 'TFX', 'Security': 'Teleflex'},
    {'Symbol': 'TER', 'Security': 'Teradyne'},
    {'Symbol': 'TSLA', 'Security': 'Tesla, Inc.'},
    {'Symbol': 'TXN', 'Security': 'Texas Instruments'},
    {'Symbol': 'TXT', 'Security': 'Textron'},
    {'Symbol': 'TMO', 'Security': 'Thermo Fisher Scientific'},
    {'Symbol': 'TJX', 'Security': 'TJX Companies'},
    {'Symbol': 'TSCO', 'Security': 'Tractor Supply'},
    {'Symbol': 'TT', 'Security': 'Trane Technologies'},
    {'Symbol': 'TDG', 'Security': 'TransDigm Group'},
    {'Symbol': 'TRV', 'Security': 'Travelers Companies (The)'},
    {'Symbol': 'TRMB', 'Security': 'Trimble Inc.'},
    {'Symbol': 'TFC', 'Security': 'Truist'},
    {'Symbol': 'TYL', 'Security': 'Tyler Technologies'},
    {'Symbol': 'TSN', 'Security': 'Tyson Foods'},
    {'Symbol': 'USB', 'Security': 'U.S. Bank'},
    #{'Symbol': 'UBER', 'Security': 'UBER'},
    {'Symbol': 'UDR', 'Security': 'UDR, Inc.'},
    {'Symbol': 'ULTA', 'Security': 'Ulta Beauty'},
    {'Symbol': 'UNP', 'Security': 'Union Pacific Corporation'},
    {'Symbol': 'UAL', 'Security': 'United Airlines Holdings'},
    {'Symbol': 'UPS', 'Security': 'United Parcel Service'},
    {'Symbol': 'URI', 'Security': 'United Rentals'},
    {'Symbol': 'UNH', 'Security': 'UnitedHealth Group'},
    {'Symbol': 'UHS', 'Security': 'Universal Health Services'},
    {'Symbol': 'VLO', 'Security': 'Valero Energy'},
    {'Symbol': 'VTR', 'Security': 'Ventas'},
    {'Symbol': 'VLTO', 'Security': 'Veralto'},
    {'Symbol': 'VRSN', 'Security': 'Verisign'},
    {'Symbol': 'VRSK', 'Security': 'Verisk'},
    #{'Symbol': 'VST', 'Security': 'VST'},
    {'Symbol': 'VZ', 'Security': 'Verizon'},
    {'Symbol': 'VRTX', 'Security': 'Vertex Pharmaceuticals'},
    {'Symbol': 'VFC', 'Security': 'VF Corporation'},
    {'Symbol': 'VTRS', 'Security': 'Viatris'},
    {'Symbol': 'VICI', 'Security': 'Vici Properties'},
    {'Symbol': 'V', 'Security': 'Visa Inc.'},
    {'Symbol': 'VMC', 'Security': 'Vulcan Materials Company'},
    {'Symbol': 'WRB', 'Security': 'Berkley'},
    {'Symbol': 'WAB', 'Security': 'Wabtec'},
    {'Symbol': 'WBA', 'Security': 'Walgreens Boots Alliance'},
    {'Symbol': 'WMT', 'Security': 'Walmart'},
    {'Symbol': 'DIS', 'Security': 'Walt Disney'},
    {'Symbol': 'WBD', 'Security': 'Warner Bros. Discovery'},
    {'Symbol': 'WM', 'Security': 'Waste Management'},
    {'Symbol': 'WAT', 'Security': 'Waters Corporation'},
    {'Symbol': 'WEC', 'Security': 'WEC Energy Group'},
    {'Symbol': 'WFC', 'Security': 'Wells Fargo'},
    {'Symbol': 'WELL', 'Security': 'Welltower'},
    {'Symbol': 'WST', 'Security': 'West Pharmaceutical Services'},
    {'Symbol': 'WDC', 'Security': 'Western Digital'},
    {'Symbol': 'WRK', 'Security': 'WestRock'},
    {'Symbol': 'WY', 'Security': 'Weyerhaeuser'},
    {'Symbol': 'WHR', 'Security': 'Whirlpool Corporation'},
    {'Symbol': 'WMB', 'Security': 'Williams Companies'},
    {'Symbol': 'WTW', 'Security': 'Willis Towers Watson'},
    {'Symbol': 'GWW', 'Security': 'W. W. Grainger'},
    {'Symbol': 'WYNN', 'Security': 'Wynn Resorts'},
    {'Symbol': 'XEL', 'Security': 'Xcel Energy'},
    {'Symbol': 'XYL', 'Security': 'Xylem Inc.'},
    {'Symbol': 'YUM', 'Security': 'Yum! Brands'},
    {'Symbol': 'ZBRA', 'Security': 'Zebra Technologies'},
    {'Symbol': 'ZBH', 'Security': 'Zimmer Biomet'},
    {'Symbol': 'ZION', 'Security': 'Zions Bancorporation'},
    {'Symbol': 'ZTS', 'Security': 'Zoetis'}
    
]

for stocks in sp500:
    data = yf.download(stocks['Symbol'], start="2000-01-01", end= "2024-07-17")
    #data.to_excel("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".xlsx")
    data.to_csv("c:/proj/fintech/stocks/" + stocks['Symbol'] + ".csv")
    time.sleep(1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
